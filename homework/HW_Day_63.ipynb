# %% [markdown]
# 在精簡深度學習的方式上 : 卷積類神經 (CNN) 採用像素遠近，而遞歸類神經 (RNN) 採用著則是時間遠近
# 那麼，既然有著類似的設計精神，兩者是否有可能互換應用呢?

# %% [markdown]
# 在許多應用中，資料同時具有空間（像素）局部性與時間序列性，例如影片、氣象資料、醫學影像等。在這種情況下，結合 CNN 與 RNN 或者使用專門設計的混合模型能夠更好地捕捉資料中的雙重結構信息。
