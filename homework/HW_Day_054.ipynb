# %% [markdown]
# 作業
# 試著想想看, 非監督學習是否有可能使用評價函數 (Metric) 來鑑別好壞呢?
# (Hint : 可以分為 "有目標值" 與 "無目標值" 兩個方向思考)

# %% [markdown]
# 非監督式學習雖然主要處理未標記數據，但並非完全無法評估。
# •
# 「無目標值」的情況下，評估側重於數據的內部結構和一致性。
# •
# 「有目標值」的情況下，可以透過外部標準來評估結果。
