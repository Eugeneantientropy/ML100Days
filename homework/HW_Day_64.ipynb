# %%
# prompt: 秀出螢幕擷取圖片

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Assuming you have a screenshot saved as 'screenshot.png' in your current directory
# Replace 'screenshot.png' with the actual file name if different.

try:
  img = mpimg.imread('/content/螢幕擷取畫面 2025-02-09 174318.png')
  plt.imshow(img)
  plt.axis('off') # Hide the axis ticks and labels
  plt.show()
except FileNotFoundError:
  print("Error: 'screenshot.png' not found. Please upload the screenshot file to your Colab environment or provide the correct file name.")
